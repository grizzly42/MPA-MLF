# %% [markdown]
# <a href="https://colab.research.google.com/github/grizzly42/MPA-MLF/blob/main/ex_5_FNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
Y = [0, 1, 1, 0]

# %%
x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0])

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(x, y, epochs=1000, batch_size=1, verbose=2)
# Out:
# Epoch 1/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 2/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 3/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3834
# Epoch 4/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3836
# Epoch 5/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3834
# Epoch 6/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 7/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 8/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3833
# Epoch 9/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 10/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 11/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3835
# Epoch 12/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3837
# Epoch 13/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3838
# Epoch 14/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3835
# Epoch 15/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3834
# Epoch 16/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3833
# Epoch 17/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 18/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3834
# Epoch 19/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3835
# Epoch 20/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3834
# Epoch 21/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 22/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 23/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 24/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 25/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3834
# Epoch 26/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3833
# Epoch 27/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 28/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 29/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 30/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 31/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 32/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 33/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 34/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 35/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 36/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3835
# Epoch 37/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 38/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 39/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 40/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 41/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 42/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 43/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 44/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 45/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 46/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 47/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 48/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 49/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 50/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 51/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 52/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 53/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 54/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 55/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3835
# Epoch 56/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3833
# Epoch 57/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 58/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 59/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 60/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 61/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 62/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 63/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 64/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 65/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 66/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 67/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 68/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 69/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 70/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 71/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 72/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 73/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 74/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 75/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 76/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 77/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 78/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 79/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 80/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 81/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 82/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3831
# Epoch 83/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 84/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 85/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 86/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 87/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 88/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 89/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 90/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 91/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 92/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 93/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 94/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 95/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 96/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 97/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 98/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 99/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 100/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 101/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 102/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 103/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 104/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 105/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 106/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 107/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 108/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 109/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 110/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 111/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 112/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 113/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 114/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 115/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 116/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 117/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 118/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 119/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 120/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 121/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 122/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 123/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 124/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 125/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 126/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 127/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 128/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 129/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 130/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 131/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 132/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3835
# Epoch 133/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3832
# Epoch 134/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 135/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 136/1000
# 4/4 - 0s - 18ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 137/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 138/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 139/1000
# 4/4 - 0s - 34ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 140/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 141/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 142/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 143/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 144/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 145/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 146/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 147/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 148/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 149/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 150/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 151/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 152/1000
# 4/4 - 0s - 34ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 153/1000
# 4/4 - 0s - 35ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 154/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 155/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 156/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3828
# Epoch 157/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 158/1000
# 4/4 - 0s - 32ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 159/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 160/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 161/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 162/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 163/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 164/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 165/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 166/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 167/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 168/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 169/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 170/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 171/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 172/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 173/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 174/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 175/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 176/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 177/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 178/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 179/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 180/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 181/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 182/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 183/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 184/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 185/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 186/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 187/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3831
# Epoch 188/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 189/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3830
# Epoch 190/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 191/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 192/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 193/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 194/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 195/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 196/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 197/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 198/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 199/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 200/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 201/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 202/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 203/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 204/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 205/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 206/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 207/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 208/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 209/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 210/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 211/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 212/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 213/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 214/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 215/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 216/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 217/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 218/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 219/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 220/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 221/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 222/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 223/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 224/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 225/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 226/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 227/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 228/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 229/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 230/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3827
# Epoch 231/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 232/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 233/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 234/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 235/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 236/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 237/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 238/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 239/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 240/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3830
# Epoch 241/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3832
# Epoch 242/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3833
# Epoch 243/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3829
# Epoch 244/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 245/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 246/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 247/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 248/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 249/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 250/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 251/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 252/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 253/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 254/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 255/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 256/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 257/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 258/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 259/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 260/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 261/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 262/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 263/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 264/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 265/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 266/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 267/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 268/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 269/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 270/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 271/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 272/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 273/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 274/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 275/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 276/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 277/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 278/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 279/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 280/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 281/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 282/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 283/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 284/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 285/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 286/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 287/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 288/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 289/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 290/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 291/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 292/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 293/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 294/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 295/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 296/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 297/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 298/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 299/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 300/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 301/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 302/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 303/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 304/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 305/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 306/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 307/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 308/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 309/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3829
# Epoch 310/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3826
# Epoch 311/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 312/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 313/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 314/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 315/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 316/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 317/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 318/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 319/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 320/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 321/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 322/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 323/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 324/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 325/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 326/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 327/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 328/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 329/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 330/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 331/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 332/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 333/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 334/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 335/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 336/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 337/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 338/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 339/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 340/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 341/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 342/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 343/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 344/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 345/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 346/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 347/1000
# 4/4 - 0s - 18ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 348/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 349/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 350/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 351/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 352/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 353/1000
# 4/4 - 0s - 30ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 354/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 355/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 356/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 357/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 358/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 359/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 360/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 361/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 362/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 363/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 364/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 365/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 366/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 367/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3825
# Epoch 368/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 369/1000
# 4/4 - 0s - 33ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 370/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 371/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 372/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 373/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 374/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 375/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 376/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 377/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 378/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 379/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 380/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 381/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 382/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 383/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 384/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 385/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 386/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 387/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 388/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 389/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 390/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 391/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 392/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 393/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 394/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 395/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 396/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 397/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 398/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 399/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 400/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 401/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 402/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 403/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 404/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 405/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 406/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 407/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 408/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 409/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 410/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 411/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 412/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 413/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 414/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 415/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 416/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 417/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 418/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 419/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 420/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 421/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 422/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 423/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 424/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 425/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 426/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 427/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 428/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 429/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 430/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 431/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 432/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 433/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 434/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 435/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 436/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 437/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 438/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 439/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 440/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 441/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 442/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 443/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 444/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 445/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 446/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 447/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 448/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 449/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 450/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 451/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 452/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 453/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 454/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 455/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 456/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 457/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 458/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 459/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 460/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 461/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 462/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 463/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 464/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 465/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 466/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 467/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 468/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 469/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 470/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 471/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 472/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 473/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 474/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 475/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 476/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 477/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 478/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 479/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 480/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3823
# Epoch 481/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 482/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 483/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 484/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 485/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 486/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 487/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 488/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 489/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 490/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 491/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 492/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 493/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 494/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 495/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 496/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 497/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 498/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 499/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 500/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 501/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 502/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 503/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 504/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 505/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 506/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 507/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 508/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 509/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 510/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 511/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 512/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 513/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 514/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 515/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 516/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 517/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 518/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 519/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 520/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 521/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 522/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 523/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 524/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 525/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 526/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 527/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 528/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 529/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 530/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 531/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 532/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 533/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 534/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 535/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 536/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 537/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 538/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 539/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 540/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 541/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 542/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 543/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 544/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 545/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 546/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 547/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 548/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 549/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 550/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 551/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 552/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3827
# Epoch 553/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3828
# Epoch 554/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3824
# Epoch 555/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 556/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 557/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 558/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 559/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 560/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 561/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 562/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 563/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 564/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 565/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 566/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 567/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 568/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 569/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 570/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 571/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 572/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 573/1000
# 4/4 - 0s - 18ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 574/1000
# 4/4 - 0s - 34ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 575/1000
# 4/4 - 0s - 33ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 576/1000
# 4/4 - 0s - 34ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 577/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 578/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 579/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 580/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 581/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 582/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 583/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 584/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 585/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 586/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 587/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 588/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 589/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 590/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 591/1000
# 4/4 - 0s - 33ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 592/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 593/1000
# 4/4 - 0s - 35ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 594/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 595/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 596/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 597/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 598/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3822
# Epoch 599/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 600/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 601/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 602/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 603/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 604/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 605/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 606/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 607/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 608/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 609/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 610/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 611/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 612/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 613/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 614/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 615/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 616/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 617/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 618/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 619/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 620/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 621/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 622/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 623/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 624/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 625/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 626/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 627/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 628/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 629/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 630/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 631/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 632/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 633/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 634/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 635/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 636/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 637/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 638/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 639/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 640/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 641/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 642/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 643/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 644/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 645/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 646/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 647/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 648/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 649/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 650/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 651/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 652/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 653/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 654/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 655/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 656/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 657/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 658/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 659/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 660/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 661/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 662/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 663/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 664/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 665/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 666/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 667/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 668/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 669/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 670/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 671/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3818
# Epoch 672/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 673/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 674/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 675/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 676/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 677/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 678/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 679/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 680/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 681/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 682/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 683/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 684/1000
# 4/4 - 0s - 17ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 685/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 686/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 687/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 688/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 689/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 690/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 691/1000
# ...
# Epoch 772/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 773/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 774/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 775/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 776/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 777/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 778/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 779/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 780/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 781/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 782/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 783/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 784/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 785/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 786/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 787/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 788/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 789/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 790/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 791/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 792/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 793/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 794/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 795/1000
# 4/4 - 0s - 18ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 796/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 797/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 798/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 799/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 800/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 801/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 802/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 803/1000
# 4/4 - 0s - 33ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 804/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 805/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 806/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 807/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 808/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 809/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 810/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 811/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 812/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 813/1000
# 4/4 - 0s - 35ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 814/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 815/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 816/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 817/1000
# 4/4 - 0s - 35ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 818/1000
# 4/4 - 0s - 35ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 819/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 820/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 821/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 822/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 823/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 824/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3820
# Epoch 825/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 826/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 827/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 828/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 829/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 830/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3824
# Epoch 831/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 832/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3825
# Epoch 833/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 834/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.5000 - loss: 0.3826
# Epoch 835/1000
# 4/4 - 0s - 31ms/step - accuracy: 0.7500 - loss: 0.3821
# Epoch 836/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 837/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 838/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 839/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 840/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 841/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 842/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 843/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 844/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 845/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 846/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 847/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 848/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 849/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 850/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 851/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 852/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 853/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 854/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 855/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 856/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 857/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 858/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 859/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 860/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 861/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 862/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 863/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 864/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 865/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 866/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 867/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 868/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 869/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 870/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3819
# Epoch 871/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 872/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 873/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 874/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 875/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 876/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 877/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 878/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 879/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 880/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 881/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 882/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 883/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 884/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 885/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 886/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 887/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 888/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 889/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 890/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 891/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 892/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 893/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 894/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 895/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 896/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 897/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 898/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 899/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 900/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 901/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 902/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 903/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 904/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 905/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 906/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3817
# Epoch 907/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 908/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 909/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 910/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 911/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 912/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 913/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 914/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 915/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 916/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 917/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 918/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 919/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 920/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 921/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 922/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 923/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 924/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 925/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 926/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 927/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 928/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 929/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 930/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 931/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 932/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 933/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 934/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 935/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 936/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 937/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 938/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 939/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 940/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 941/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 942/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 943/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 944/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 945/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 946/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 947/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 948/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 949/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 950/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 951/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 952/1000
# 4/4 - 0s - 13ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 953/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 954/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 955/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 956/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3817
# Epoch 957/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3815
# Epoch 958/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 959/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 960/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 961/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 962/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 963/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 964/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 965/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 966/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3820
# Epoch 967/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3821
# Epoch 968/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3822
# Epoch 969/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3823
# Epoch 970/1000
# 4/4 - 0s - 12ms/step - accuracy: 0.7500 - loss: 0.3819
# Epoch 971/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 972/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3818
# Epoch 973/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3816
# Epoch 974/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 975/1000
# 4/4 - 0s - 16ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 976/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 977/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 978/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 979/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 980/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 981/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 982/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 983/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 984/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 985/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 986/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 987/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 988/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 989/1000
# 4/4 - 0s - 15ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 990/1000
# 4/4 - 0s - 10ms/step - accuracy: 0.5000 - loss: 0.3813
# Epoch 991/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 992/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 993/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 994/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.5000 - loss: 0.3816
# Epoch 995/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 996/1000
# 4/4 - 0s - 11ms/step - accuracy: 0.7500 - loss: 0.3813
# Epoch 997/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3814
# Epoch 998/1000
# 4/4 - 0s - 9ms/step - accuracy: 0.5000 - loss: 0.3815
# Epoch 999/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3814
# Epoch 1000/1000
# 4/4 - 0s - 14ms/step - accuracy: 0.7500 - loss: 0.3813

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(x, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 75.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  data_sample = np.array(data_sample).reshape(1,-1)
  prediction = model.predict(data_sample)
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Data sample is [[0 0]], prediction from model [[0.00309435]], ground_truth 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Data sample is [[0 1]], prediction from model [[0.99572325]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Data sample is [[1 0]], prediction from model [[0.5057376]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Data sample is [[1 1]], prediction from model [[0.508618]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = '/content/voting_complete.csv' # change the PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %% [markdown]
# 1. classification task
# 2. 435 samples
# 3. 16 features
# 4. object, boolean
# 5. yeah there are some questionsmarks
# 6. 2 (republican, democrat)

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     ?                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 343                   n                          n
# 344                   n                          n
# 345                   n                          ?
# 346                   n                          n
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 343                                 y                    y               y
# 344                                 y                    n               n
# 345                                 n                    y               y
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           y                       n
# 344                           n                       y
# 345                           y                       n
# 346                           y                       ?
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         n          y           y
# 344                         y          y           y
# 345                         n          n           n
# 346                         ?          ?           ?
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      y
# 344                            n                  n                      n
# 345                            y                  y                      y
# 346                            n                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     y                 n                                      y
# 344     n                 n                                      y
# 345     y                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %%
y_train
# Out:
# 0      republican
# 1      republican
# 2        democrat
# 3        democrat
# 4        democrat
#           ...
# 343    republican
# 344      democrat
# 345    republican
# 346    republican
# 347    republican
# Name: Class Name, Length: 348, dtype: object

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE
correspondance = {'n': -1, 'y': 1, '?': 0}

for col in x_train.columns:
    if x_train[col].dtype == 'object':
        x_train[col] = x_train[col].map(correspondance)

for col in x_train.columns:
    mean_col = np.mean(x_train[col][x_train[col] != 0])
    x_train[col][x_train[col] == 0] = round(mean_col)

x_train
# Out:
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
# <ipython-input-49-867ecd263597>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_train[col][x_train[col] == 0] = round(mean_col)
#      handicapped-infants  water-project-cost-sharing  \
# 0                     -1                           1
# 1                     -1                           1
# 2                      0                           1
# 3                     -1                           1
# 4                      1                           1
# ..                   ...                         ...
# 343                   -1                          -1
# 344                   -1                          -1
# 345                   -1                           0
# 346                   -1                          -1
# 347                   -1                           1
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                   -1                     1                1
# 1                                   -1                     1                1
# 2                                    1                     0                1
# 3                                    1                    -1                0
# 4                                    1                    -1                1
# ..                                 ...                   ...              ...
# 343                                  1                     1                1
# 344                                  1                    -1               -1
# 345                                 -1                     1                1
# 346                                 -1                     1                1
# 347                                 -1                     1                1
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 0                              1                       -1
# 1                              1                       -1
# 2                              1                       -1
# 3                              1                       -1
# 4                              1                       -1
# ..                           ...                      ...
# 343                            1                       -1
# 344                           -1                        1
# 345                            1                       -1
# 346                            1                        0
# 347                            1                       -1
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                           -1          -1            1
# 1                           -1          -1           -1
# 2                           -1          -1           -1
# 3                           -1          -1           -1
# 4                           -1          -1           -1
# ..                         ...         ...          ...
# 343                         -1           1            1
# 344                          1           1            1
# 345                         -1          -1           -1
# 346                          0           0            0
# 347                         -1          -1            1
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                               0                   1                       1
# 1                              -1                   1                       1
# 2                               1                  -1                       1
# 3                               1                  -1                       1
# 4                               1                   0                       1
# ..                            ...                 ...                     ...
# 343                            -1                   1                       1
# 344                            -1                  -1                      -1
# 345                             1                   1                       1
# 346                            -1                   1                       1
# 347                            -1                   1                       1
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 0        1                 -1                                       1
# 1        1                 -1                                       1
# 2        1                 -1                                      -1
# 3       -1                 -1                                       1
# 4        1                  1                                       1
# ..     ...                ...                                     ...
# 343      1                 -1                                       1
# 344     -1                 -1                                       1
# 345      1                 -1                                       1
# 346      1                 -1                                       1
# 347      1                  0                                      -1
#
# [348 rows x 16 columns]

# %%
x_train.replace('?',np.nan,inplace=True)
x_train.fillna(x_train.mode().iloc[0],inplace=True)
x= pd.get_dummies(x_train)
x
# Out:
#      handicapped-infants  water-project-cost-sharing  \
# 0                     -1                           1
# 1                     -1                           1
# 2                      0                           1
# 3                     -1                           1
# 4                      1                           1
# ..                   ...                         ...
# 343                   -1                          -1
# 344                   -1                          -1
# 345                   -1                           0
# 346                   -1                          -1
# 347                   -1                           1
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                   -1                     1                1
# 1                                   -1                     1                1
# 2                                    1                     0                1
# 3                                    1                    -1                0
# 4                                    1                    -1                1
# ..                                 ...                   ...              ...
# 343                                  1                     1                1
# 344                                  1                    -1               -1
# 345                                 -1                     1                1
# 346                                 -1                     1                1
# 347                                 -1                     1                1
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 0                              1                       -1
# 1                              1                       -1
# 2                              1                       -1
# 3                              1                       -1
# 4                              1                       -1
# ..                           ...                      ...
# 343                            1                       -1
# 344                           -1                        1
# 345                            1                       -1
# 346                            1                        0
# 347                            1                       -1
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                           -1          -1            1
# 1                           -1          -1           -1
# 2                           -1          -1           -1
# 3                           -1          -1           -1
# 4                           -1          -1           -1
# ..                         ...         ...          ...
# 343                         -1           1            1
# 344                          1           1            1
# 345                         -1          -1           -1
# 346                          0           0            0
# 347                         -1          -1            1
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                               0                   1                       1
# 1                              -1                   1                       1
# 2                               1                  -1                       1
# 3                               1                  -1                       1
# 4                               1                   0                       1
# ..                            ...                 ...                     ...
# 343                            -1                   1                       1
# 344                            -1                  -1                      -1
# 345                             1                   1                       1
# 346                            -1                   1                       1
# 347                            -1                   1                       1
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 0        1                 -1                                       1
# 1        1                 -1                                       1
# 2        1                 -1                                      -1
# 3       -1                 -1                                       1
# 4        1                  1                                       1
# ..     ...                ...                                     ...
# 343      1                 -1                                       1
# 344     -1                 -1                                       1
# 345      1                 -1                                       1
# 346      1                 -1                                       1
# 347      1                  0                                      -1
#
# [348 rows x 16 columns]

# %%
#WRITE YOUR CODE HERE
correspondance = {'republican': 0, 'democrat': 1,}
y_train= y_train.map(correspondance)
y_train
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 343   NaN
# 344   NaN
# 345   NaN
# 346   NaN
# 347   NaN
# Name: Class Name, Length: 348, dtype: float64

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model2 = Sequential()
model2.add(InputLayer(input_shape=(16,)))
model2.add(Dense(2, activation='sigmoid'))
model2.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model2.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                      │ (None, 2)                   │              34 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 37 (148.00 B)
#  Trainable params: 37 (148.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer2 = tf.keras.optimizers.SGD(learning_rate=0.1)
model2.compile(loss='binary_crossentropy', optimizer=optimizer2, metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#cWRITE YOUR CODE HERE
history2 = model2.fit(x_train, y_train, epochs=100, batch_size=1, verbose=0,validation_split=0.2)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
correspondance = {'n': -1, 'y': 1, '?': 0}

for col in x_test.columns:
    if x_test[col].dtype == 'object':
        x_test[col] = x_test[col].map(correspondance)

for col in x_test.columns:
    mean_col = np.mean(x_test[col][x_test[col] != 0])
    x_test[col][x_test[col] == 0] = round(mean_col)
x_test
correspondance2 = {'republican': 0, 'democrat': 1,}
y_test= y_test.map(correspondance2)
y_test
# Out:
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# <ipython-input-43-b2044c38cf5b>:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   x_test[col][x_test[col] == 0] = round(mean_col)
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 82   NaN
# 83   NaN
# 84   NaN
# 85   NaN
# 86   NaN
# Name: Class Name, Length: 87, dtype: float64

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model2.evaluate(x_train, y_train, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 97.99

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
plt.figure()
plt.plot(history2.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')
